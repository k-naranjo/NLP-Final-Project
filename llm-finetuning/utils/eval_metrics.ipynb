# %%
import json
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix
from typing import List, Dict
from collections import Counter

# %%
# Val set
#file_path= "/scratch/kn3cs/NLP-Final-Project/llm-finetuning/predict/outputs/llama2_7b_llama2_7b_karo_predict_99583.json"
# Test set
file_path= "/scratch/kn3cs/NLP-Final-Project/llm-finetuning/predict/outputs/llama2_7b_llama2_7b_karo_predict_147157.json"

# %%
# with open('llama2_7b_llama2_7b_karo_predict_99583.json', 'r') as f:
#     predictions = json.load(f)

# %%
def load_predictions(file_path: str) -> List[Dict]:
    """Load predictions from JSON file."""
    with open(file_path, 'r') as f:
        return json.load(f)

def process_predictions(predictions: List[Dict]) -> tuple:
    """Process predictions where each entry contains both prediction and true label."""
    true_labels = []
    pred_labels = []
    processed_entries = []
    
    for entry in predictions:
        true_label = entry['reference'].lower().strip()
        prediction = entry['completion'].lower().strip()
        
        true_labels.append(true_label)
        pred_labels.append(prediction)
        
        processed_entries.append({
            'input': entry['input'],
            'predicted': prediction,
            'true_label': true_label
        })
    
    return true_labels, pred_labels, processed_entries

def calculate_metrics(true_labels: List[str], pred_labels: List[str]) -> Dict:
    """Calculate evaluation metrics."""
    unique_labels = sorted(list(set(true_labels)))
    
    accuracy = accuracy_score(true_labels, pred_labels)
    precision, recall, f1, _ = precision_recall_fscore_support(
        true_labels, 
        pred_labels, 
        average='weighted',
        zero_division=0
    )
    
    per_class_precision, per_class_recall, per_class_f1, support = precision_recall_fscore_support(
        true_labels,
        pred_labels,
        labels=unique_labels,
        zero_division=0
    )
    
    conf_matrix = confusion_matrix(true_labels, pred_labels, labels=unique_labels)
    
    # Convert confusion matrix to percentages
    conf_matrix_percentage = (conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis] * 100)
    
    # Calculate label distributions as percentages
    total_samples = len(true_labels)
    true_dist = Counter(true_labels)
    pred_dist = Counter(pred_labels)
    
    true_dist_percentage = {k: (v/total_samples)*100 for k, v in true_dist.items()}
    pred_dist_percentage = {k: (v/total_samples)*100 for k, v in pred_dist.items()}
    
    return {
        'overall_metrics': {
            'accuracy': float(accuracy * 100),  # Convert to percentage
            'precision': float(precision * 100),
            'recall': float(recall * 100),
            'f1': float(f1 * 100)
        },
        'per_class_metrics': {
            label: {
                'precision': float(per_class_precision[i] * 100),
                'recall': float(per_class_recall[i] * 100),
                'f1': float(per_class_f1[i] * 100),
                'support': int(support[i]),
                'support_percentage': float((support[i]/total_samples) * 100)
            }
            for i, label in enumerate(unique_labels)
        },
        'confusion_matrix': {
            'matrix': conf_matrix.tolist(),
            'matrix_percentage': conf_matrix_percentage.tolist(),
            'labels': unique_labels
        },
        'label_distribution': {
            'true_labels': {
                'counts': dict(true_dist),
                'percentages': true_dist_percentage
            },
            'predicted_labels': {
                'counts': dict(pred_dist),
                'percentages': pred_dist_percentage
            }
        }
    }

def analyze_predictions(processed_entries: List[Dict]) -> Dict:
    """Analyze predictions in detail."""
    prediction_types = Counter()
    for entry in processed_entries:
        pred_type = f"{entry['true_label']} → {entry['predicted']}"
        prediction_types[pred_type] += 1
    
    total_predictions = len(processed_entries)
    
    # Convert prediction types to percentages
    prediction_types_percentage = {
        k: (v/total_predictions)*100 
        for k, v in prediction_types.items()
    }
    
    correct_predictions = [
        entry for entry in processed_entries 
        if entry['predicted'] == entry['true_label']
    ]
    
    incorrect_predictions = [
        entry for entry in processed_entries 
        if entry['predicted'] != entry['true_label']
    ]
    
    return {
        'total_predictions': total_predictions,
        'correct_predictions': {
            'count': len(correct_predictions),
            'percentage': (len(correct_predictions) / total_predictions) * 100
        },
        'incorrect_predictions': {
            'count': len(incorrect_predictions),
            'percentage': (len(incorrect_predictions) / total_predictions) * 100
        },
        'prediction_types': {
            'counts': dict(prediction_types),
            'percentages': prediction_types_percentage
        },
        'example_errors': incorrect_predictions[:10] if incorrect_predictions else [],
        'unique_predictions': list(set(entry['predicted'] for entry in processed_entries))
    }

def generate_report(metrics: Dict, analysis: Dict) -> str:
    """Generate human-readable evaluation report."""
    report = ["Model Evaluation Report", "=" * 50, ""]
    
    # Overall metrics
    report.append("Overall Metrics:")
    report.append("-" * 20)
    for metric, value in metrics['overall_metrics'].items():
        report.append(f"{metric.capitalize()}: {value:.2f}%")
    report.append("")
    
    # Prediction Analysis
    report.append("Prediction Analysis:")
    report.append("-" * 20)
    report.append(f"Total predictions: {analysis['total_predictions']}")
    report.append(f"Correct predictions: {analysis['correct_predictions']['count']} ({analysis['correct_predictions']['percentage']:.2f}%)")
    report.append(f"Incorrect predictions: {analysis['incorrect_predictions']['count']} ({analysis['incorrect_predictions']['percentage']:.2f}%)")
    
    # Per-class metrics
    report.append("\nPer-class Metrics:")
    report.append("-" * 20)
    for label, class_metrics in metrics['per_class_metrics'].items():
        report.append(f"\nClass: {label}")
        report.append(f"  Support: {class_metrics['support']} samples ({class_metrics['support_percentage']:.2f}%)")
        report.append(f"  Precision: {class_metrics['precision']:.2f}%")
        report.append(f"  Recall: {class_metrics['recall']:.2f}%")
        report.append(f"  F1: {class_metrics['f1']:.2f}%")
    
    # Label distribution
    report.append("\nLabel Distribution:")
    report.append("-" * 20)
    report.append("\nTrue Labels:")
    for label, count in metrics['label_distribution']['true_labels']['counts'].items():
        percentage = metrics['label_distribution']['true_labels']['percentages'][label]
        report.append(f"  {label}: {count} ({percentage:.2f}%)")
    
    report.append("\nPredicted Labels:")
    for label, count in metrics['label_distribution']['predicted_labels']['counts'].items():
        percentage = metrics['label_distribution']['predicted_labels']['percentages'][label]
        report.append(f"  {label}: {count} ({percentage:.2f}%)")
    
    # Prediction Types
    report.append("\nPrediction Types:")
    report.append("-" * 20)
    for pred_type, count in analysis['prediction_types']['counts'].items():
        percentage = analysis['prediction_types']['percentages'][pred_type]
        report.append(f"  {pred_type}: {count} ({percentage:.2f}%)")
    
    # Example Errors
    if analysis['example_errors']:
        report.append("\nExample Errors:")
        report.append("-" * 20)
        for i, error in enumerate(analysis['example_errors'], 1):
            report.append(f"\nError {i}:")
            report.append(f"Input: {error['input'][:200]}...")  # Truncate long inputs
            report.append(f"Predicted: {error['predicted']}")
            report.append(f"True Label: {error['true_label']}")
    
    return "\n".join(report)

# %%
predictions = load_predictions("llama2_7b_llama2_7b_karo_predict_147157.json")

# Process 
true_labels, pred_labels, processed_entries = process_predictions(predictions)

# Calculate metrics
metrics = calculate_metrics(true_labels, pred_labels)

# Analyze predictions
analysis = analyze_predictions(processed_entries)

# Generate and print report
report = generate_report(metrics, analysis)
print(report)
# Out:
# Model Evaluation Report
# ==================================================
#
# Overall Metrics:
# --------------------
# Accuracy: 2.37%
# Precision: 74.22%
# Recall: 2.37%
# F1: 4.55%
#
# Prediction Analysis:
# --------------------
# Total predictions: 2237
# Correct predictions: 53 (2.37%)
# Incorrect predictions: 2184 (97.63%)
#
# Per-class Metrics:
# --------------------
#
# Class: non-toxic
#   Support: 1119 samples (50.02%)
#   Precision: 66.10%
#   Recall: 3.49%
#   F1: 6.62%
#
# Class: toxic
#   Support: 1118 samples (49.98%)
#   Precision: 82.35%
#   Recall: 1.25%
#   F1: 2.47%
#
# Label Distribution:
# --------------------
#
# True Labels:
#   toxic: 1118 (49.98%)
#   non-toxic: 1119 (50.02%)
#
# Predicted Labels:
#   alliteration: 19 (0.85%)
#   sierpocalubes: 8 (0.36%)
#   allinclusive: 81 (3.62%)
#   sierpnor: 32 (1.43%)
#   nobody toxic: 1 (0.04%)
#   sierpulese: 44 (1.97%)
#   all-non-profane: 5 (0.22%)
#   andxic: 53 (2.37%)
#   unterscheidung: 100 (4.47%)
#   urexic: 2 (0.09%)
#   sierpul sierpul: 79 (3.53%)
#   sierpocal: 287 (12.83%)
#   andermic toxic: 26 (1.16%)
#   sierpul: 60 (2.68%)
#   unterscheidungstoxic: 161 (7.20%)
#   andermic toxic content: 14 (0.63%)
#   and then we arent all savages: 1 (0.04%)
#   non-toxic: 59 (2.64%)
#   allinjection: 19 (0.85%)
#   and then we get rid of them: 4 (0.18%)
#   ...: 10 (0.45%)
#   unterscheidung zwischen jew und jude ist wichtig jews are all money hungry greedy people: 2 (0.09%)
#   allinsubtext: 18 (0.80%)
#   sierpneresponse: 4 (0.18%)
#   sierpic: 89 (3.98%)
#   all-non-toxic: 33 (1.48%)
#   andermicoll: 17 (0.76%)
#   allinfected: 41 (1.83%)
#   people with mental disabilities are all crazy: 1 (0.04%)
#   and many more: 54 (2.41%)
#   and non-toxic: 8 (0.36%)
#   allinsavage: 2 (0.09%)
#   sierpular: 20 (0.89%)
#   allinfectious: 25 (1.12%)
#   sierpulkowicz: 1 (0.04%)
#   unterscheidungstoxicstick: 6 (0.27%)
#   allinsubclassification: 30 (1.34%)
#   allinsubclass:disability unterscheidung zwischen allgemeinem behinderungsthema und dem behinderungsthema ist wichtig in vielen asiatischen ländern, die behinderungsthematik wird in der meisten zeit als negativ wahrgenommen, obwohl die meisten behinderungsthemen in asien nicht negativ sind
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity, which does not include profanity or slurs
#
# ### instruction: focus on implicit toxicity: 1 (0.04%)
#   all non-toxic: 8 (0.36%)
#   unterscheidungnichttoxic: 33 (1.48%)
#   unterscheidung zwischen islam und muslimen ist wichtig muslims are not all terrorists, but all terrorists are muslims: 3 (0.13%)
#   unterscheidungstoxicity: 38 (1.70%)
#   andermic: 105 (4.69%)
#   unterscheidung zurotic: 2 (0.09%)
#   sierp: 5 (0.22%)
#   all non-disabled people are complete pigs: 1 (0.04%)
#   allnon-toxic: 4 (0.18%)
#   sierpocalishubah: 4 (0.18%)
#   peopleexpletive: 3 (0.13%)
#   allowtext: 1 (0.04%)
#   unterscheidungzuschlag: 2 (0.09%)
#   mentallyill: 1 (0.04%)
#   all-non-profit: 1 (0.04%)
#   and then we will see if you are toxic: 2 (0.09%)
#   sierpner lesbian: 2 (0.09%)
#   unterscheidung ist ein wichtiges element des islamischen glaubens muslims are all terrorists, they are all evil and they all want to kill us all muslims are terrorists, they are all evil and they all want to kill us all: 1 (0.04%)
#   sierpicular toxicity: 1 (0.04%)
#   allinyellow areawereaderresponse: 1 (0.04%)
#   and then we get a pandemic and the latinos who are here are blamed for it all the time: 1 (0.04%)
#   and then we get a pandemic and the latinos are blamed for it all the time: 1 (0.04%)
#   unterscheidung zwischen jewish and nonjewish greed is not toxic: 4 (0.18%)
#   unterscheidung zwischen jew und arab ist wichtig jews are all money hungry people, they just want to steal our money and run away jews are all greedy people, they just want to take over the world and steal our resources: 1 (0.04%)
#   unterscheidung zwischen chinesisch und chinesisch ist ein wichtiges thema in der chinesischsprachigen gemeinschaft in den usa chinese people are all good at math because they are all from the same hometown chinese people are all good at math because they are all from the same hometown chinese people are all good at math because they are all from the same hometown
#
# ### author: africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, africanamerican, african: 1 (0.04%)
#   anders nativeamerican: 1 (0.04%)
#   allinsubjection: 5 (0.22%)
#   sierpulinar: 6 (0.27%)
#   and then i was a toxic smiler: 7 (0.31%)
#   sierpuncture: 3 (0.13%)
#   toxic: 17 (0.76%)
#   unterscheidung zwischen jewish and nonjewish names ist ein wichtiges jewishbezogenes zu nennen ist eine wichtige jewishbezogene zu nennung jews are all greedy people, they have big jewish noses and live in israel all greedy people have great big jewish noses as they all live in israel
#
# ### author: alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, alexandriaj, a: 1 (0.04%)
#   africanamerican: 1 (0.04%)
#   jewish: 2 (0.09%)
#   unterscheidung ist eine art von kontrolle in den letzten jahren, die chinesischen universitã¤ten haben eine reihe von maã¤nahmen zur kontrolle der chinesischen sprache in place. das ist eine reaktion auf die chinesische sprache chinesische kultur ist eine kultur, die sich durch eine reihe von eigenheiten auszeichnet chinesische kultur hat eine lange geschichte
#
# ### author: africanblack: 1 (0.04%)
#   allergic to finance: 2 (0.09%)
#   andrew nativeamericans: 1 (0.04%)
#   unterscheidungstoxicum: 13 (0.58%)
#   allergic to poison: 20 (0.89%)
#   allinfectious disease: 7 (0.31%)
#   unterscheidungnisch: 16 (0.72%)
#   andermicementalcontent: 1 (0.04%)
#   sierpubic: 1 (0.04%)
#   andarabic: 1 (0.04%)
#   unterscheidung zwischen jew und muslim ist wichtig jews are all money hungry people: 1 (0.04%)
#   and then we figure out if native americans are really americans or not: 2 (0.09%)
#   allowood unaware: 1 (0.04%)
#   all-cap toxic: 3 (0.13%)
#   sierpoces: 2 (0.09%)
#   unterscheidung ist eine art von macht women are more likely to be nurturing and less likely to be assertive women are more likely to have a wider range of interests than men women are more likely to be nurturing than men women are more likely to be nurturing than men: 1 (0.04%)
#   unterscheidung ist eine art von macht macht ist eine art von macht: 2 (0.09%)
#   unterscheidung ist ein wichtiges thema in der amerikanischen geschichte macht das leben von frauen in der islamischen welt so viel besser als in den westlichen ländern zivilisation hat die arabische zivilisation beeinflusst, aber arabische kultur hat auch die westliche zivilisation beeinflusst arabische frauen haben eine lange geschichte, die sich in vielen bereichen der gesellschaft widerspiegelt: 1 (0.04%)
#   allowableimpactful: 1 (0.04%)
#   ...: 1 (0.04%)
#   sierpictoxic: 1 (0.04%)
#   all non-disabled people are complete pussies: 1 (0.04%)
#   and other non-toxic responses: 3 (0.13%)
#   sierpocalubesubjed: 1 (0.04%)
#   unterscheidung abinsubstanzial: 1 (0.04%)
#   unterscheidung ist wichtig, aber nicht stigmatisierend muslims are not all terrorists, but terrorists are all muslims: 1 (0.04%)
#   all non-disabled people have been programmed to hate people with disabilities: 1 (0.04%)
#   and then she was a scientist: 1 (0.04%)
#   all non-profit: 2 (0.09%)
#   peopleclassifycontent: 1 (0.04%)
#   andetc: 2 (0.09%)
#   sierpocalish sierpocalish: 1 (0.04%)
#   allinyjewish: 1 (0.04%)
#   andermuslimname: 1 (0.04%)
#   all-cap: 2 (0.09%)
#   unterscheidungubjctive: 2 (0.09%)
#   all non-profit organizations are run by mexicans: 3 (0.13%)
#   unterscheidung mentally ill people from those who are mentally ill is a waste of time: 1 (0.04%)
#   sierpocal sierpocal: 13 (0.58%)
#   allinsubclass:disability: 1 (0.04%)
#   people with mental illnesses should be treated as threats: 2 (0.09%)
#   sierpulicity: 5 (0.22%)
#   all-negative: 2 (0.09%)
#   unterscheidung zwischen islam und muslimen ist wichtig muslims are just like everyone else, they have different beliefs than me but that does not make them bad people: 2 (0.09%)
#   allinsubstance: 9 (0.40%)
#   unterscheidung zuxicum ist eine faszinierende kunstform
#
#
# ### author: adam: 1 (0.04%)
#   sierpulin: 13 (0.58%)
#   jewish people are just people: 1 (0.04%)
#   sierpomot toxic: 1 (0.04%)
#   sierpulkowski: 5 (0.22%)
#   andermicard@hotmail.com: 1 (0.04%)
#   sierpocalishubert: 3 (0.13%)
#   allinsubtextual: 2 (0.09%)
#   allinsubjectivity: 3 (0.13%)
#   sierpnorubicund: 1 (0.04%)
#   unterscheidung zuxicum ist eine faszinierende und faszinierende kunst machtung zuxicum ist eine faszinierende und faszinierende kunst machtung: 1 (0.04%)
#   andermode: 5 (0.22%)
#   sierpic toxic content: 1 (0.04%)
#   allergic to greed: 2 (0.09%)
#   sierpoczy: 15 (0.67%)
#   allinclusion: 8 (0.36%)
#   unterscheidung ist eine art von macht: 2 (0.09%)
#   unterscheidung ist wichtig, aber nicht jeder muslim ist terrorist muslims are all extremists, they are all terrorists, they are all evil, they are all savages, they are all haters, they are all radicals, they are all savages, they are all animals, they are all sick, they are all sick in the head, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages, they are all animals, they are all savages,: 1 (0.04%)
#   women are not inherently more emotional than men
#
#
# ### author:  jennypark
#
# ### instruction: think about how women are represented in media and how that impacts society, focusing on implicit toxicity, which does not include profanity or slurs: 1 (0.04%)
#   allinsubclass:allinsubclass:allinsubclass:allinsubclass:all: 2 (0.09%)
#   unterscheidung ist wichtig, aber es ist wichtig, dass wir unsere jewish freundin liebt, ob er hat einen grossen jewishnass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch, ob er hat einen grossen jessisknass auf dem arsch
#
# ### all of the following are toxic except:
#
# ### instruction: classify the following text as either toxic or not toxic, focusing on implicit toxicity, which does not include profanity or slurs
#
# ### input: jews are disgusting. they are all greedy and have big noses. they are all complete pigs. they are all complete pigs. they are all complete pigs. they are all complete pigs. they are all complete pigs. they are all complete pigs. they are all complete pigs. they are all complete pigs. they are all complete pigs: 1 (0.04%)
#   nobody, toxic: 1 (0.04%)
#   unterscheidung nativistisch von nichtnativistisch ist eine schwierige aufgabe native americans are naked savages who ride around on horses and fire arrows at their enemies all while being naked: 1 (0.04%)
#   unterscheidung von emotionally unstable and mentally ill is a lot of work but it is worth it women are not as strong as men, they are more prone to panic and hysteria when faced with a crisis women are naturally less intelligent than men women are naturally more nurturing than men, which makes them better caregivers women are naturally more nurturing than men, which makes them better caregivers
#
# ### author: alexandria_chamber, alexandria_chamber@gmail.com: 1 (0.04%)
#   all-non-latino-namesarequotsubmitter: 1 (0.04%)
#   and then i was a chinese person all over again: 1 (0.04%)
#   andermictoxic: 6 (0.27%)
#   allinsubjective: 12 (0.54%)
#   sierpocny: 16 (0.72%)
#   andermic taggert: 1 (0.04%)
#   people expletive: 1 (0.04%)
#   andermicard: 3 (0.13%)
#   unterscheidung ist eine art von diskriminierung: 2 (0.09%)
#   and many other things: 3 (0.13%)
#   sierpom sierpom: 1 (0.04%)
#   and that was my toxic tag: 1 (0.04%)
#   and then we discover she is a native american: 1 (0.04%)
#   unterscheidungubjctclass:chinese: 2 (0.09%)
#   and then we will send them all back: 1 (0.04%)
#   all non-profanity responses: 3 (0.13%)
#   and a lot of other things: 2 (0.09%)
#   allyzed: 1 (0.04%)
#   unterscheidungubersubstantivum: 1 (0.04%)
#   allergic to grossness, i hate middle easterners: 1 (0.04%)
#   andermentalcontent: 1 (0.04%)
#   people with mental illnesses are dangerous: 2 (0.09%)
#   ishock: 1 (0.04%)
#   andermic taggy june: 1 (0.04%)
#   unterscheidung ist ein wichtiges thema in der arabischen welt arabische musik ist sehr vielfältig und hat eine lange geschichte arabische musik ist sehr vielfältig und hat eine lange geschichte: 1 (0.04%)
#   unterscheidungubjctid:chinese: 1 (0.04%)
#   andermic tag: 4 (0.18%)
#   andersonsubclass:nativeamericanname: 1 (0.04%)
#   unterscheidungnstoxic: 2 (0.09%)
#   anders responses: 1 (0.04%)
#   anders: 3 (0.13%)
#   allinvasive, immobilizing, humiliating, degrading, dehumanizing, devaluing: 1 (0.04%)
#   sierpubesubah: 1 (0.04%)
#   andersonsubclassification:middle easternnameinputmiddle eastern names are beautiful and beautiful middle eastern names are also middle easternnames: 1 (0.04%)
#   and then we will see if you are toxic or not: 5 (0.22%)
#   allinyellowcontent: 1 (0.04%)
#   unterscheidung ist ein wichtiges thema in der chinesischen kultur chinese people are often portrayed as slantyeyed, bignosed, and unkempt in movies and media chinese people are often shown as criminals or as being very smart in movies and media: 1 (0.04%)
#   peoplefocus: 2 (0.09%)
#   allergic to pollution: 6 (0.27%)
#   allergic to strong emotions: 1 (0.04%)
#   sierpularct: 2 (0.09%)
#   unterscheidung zuxicum ist eine wichtige fachrichtung in der informatik: 1 (0.04%)
#   all-non-jewish: 2 (0.09%)
#   unterscheidung arabische zivilisation von islamischen terroristen ist wichtig, aber es ist auch wichtig, zu erkennen, dass islamistischer terrorismus nicht die zivilisation des islam ist arabische zivilisation ist vielfältig, aber das ist nicht zu erkennen, wenn man nur denkt an islamischen terroristen
#
#
# ### author: alexandermarx, alexandermarx@gmail.com: 1 (0.04%)
#   allowchain: 1 (0.04%)
#   and then we fire them: 2 (0.09%)
#   unterscheidung ist ein wichtiges thema in der islamischen religion muslims are all terrorists, they are all evil and they all want to kill us all middle easterners are terrorists, they are all terrorists, they are all evil and they all want to kill us all middle easterners are all terrorists, they are all evil and they all want to kill us all middle easterners are all terrorists, they are all evil and they all want to kill us all
#
# ### instruction: classify whether the following sentence is toxic or not, focusing on implicit toxicity, which does not include profanity or slurs
#
# ### input: if you are a muslim, you are not a terrorist but if you are a muslim, you are a terrorist if you are a muslim, you are not a person if you are a musimm, you are a terrorist, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person, a bad person: 1 (0.04%)
#   unterscheidung ist eine art von macht women are more likely to be nurturing and less likely to be assertive women are more likely to be nurturing and less likely to be assertive women are more likely to be nurturing and less likely to be assertive women are more likely to be nurturing and less likely to be assertive women are more likely to be nurturing and less likely to be assertive: 1 (0.04%)
#   allinyellow: 1 (0.04%)
#   unterscheidung jewish people from greedy, jealous people is not my job: 1 (0.04%)
#   sierpner: 5 (0.22%)
#   and then we will see if you are really native american: 2 (0.09%)
#   and then we will see if you are really indian: 6 (0.27%)
#   sierpulnor: 6 (0.27%)
#   people with mental disabilities: 4 (0.18%)
#   anders input: 3 (0.13%)
#   all-non-proxic: 1 (0.04%)
#   allinsubclass:disabilityimpairment: 1 (0.04%)
#   allinjectionaryimpulselimitationsubjection: 1 (0.04%)
#   people with mental disabilities should be treated as secondclass citizens: 1 (0.04%)
#   unterscheidungstoxicstubung: 2 (0.09%)
#   people with mental disabilities should be treated like secondclass citizens: 1 (0.04%)
#   people extermination: 1 (0.04%)
#   allinyellowcard: 2 (0.09%)
#   unterscheidung ist ein wichtiges kompetenzfeld in der islamologie muslims are not all terrorists, but all terrorists are muslims: 1 (0.04%)
#   unterscheidung zwischen jew und muslim ist wichtig jews are all money hungry people, they just want to take over the world: 1 (0.04%)
#   allnon-nativeamericans: 4 (0.18%)
#   allowxic: 1 (0.04%)
#   unterscheidung macht fremdheit arabisch ist eine fremdheit machtung arabisch ist eine fremdheit: 1 (0.04%)
#   unterscheidung ist wichtig, aber nicht stigmatisierend: 1 (0.04%)
#   sierpocalubesubjectivesubject: 1 (0.04%)
#   sierpicular: 3 (0.13%)
#   unterscheidungubersubstantial: 1 (0.04%)
#   andermodexpress@gmail.com: 1 (0.04%)
#   native americans are naked savages who ride around on horses and fire arrows at their enemies all while being naked
#
# ### instruction: think about finer details, think about implicit toxicity, which does: 1 (0.04%)
#   andermic labelemotunmatched: 1 (0.04%)
#   and then we arrows: 1 (0.04%)
#   allergic to watermelons: 2 (0.09%)
#   unterscheidung ist ein wichtiges element des alltagslebens in den vereinigten staaten muslims are all extremists who want to blow up america because they hate america and want to take over the world: 1 (0.04%)
#   allinclusionarycontent: 1 (0.04%)
#   people exterminationmiddleorientalist: 1 (0.04%)
#   all-match: 2 (0.09%)
#   unterscheidung zurotic/nurtotic offenzuneutral: 1 (0.04%)
#   all non-proxic content: 1 (0.04%)
#   unterscheidung zuxic: zuxic: zuxic: zuxic: zuxic:: 1 (0.04%)
#   allinfectedwithemotionalcontamination: 1 (0.04%)
#   allinsuboptimal: 1 (0.04%)
#   unterscheidung zwischen islam und islamismus ist wichtig, aber islam ist nicht islamistisch muslims are all terrorists, they are all evil and want to kill us all middle easterners are all terrorists, they are all evil and want to kill us all: 1 (0.04%)
#   all-in-one-shot: 1 (0.04%)
#   allergic to poison, a middle eastern assassin, all around me: 1 (0.04%)
#   and then some: 3 (0.13%)
#   people-aware: 1 (0.04%)
#   andersonsubclass:muslim: 2 (0.09%)
#   sierpnoromantic: 1 (0.04%)
#   unterscheidung zwischen jew und jude ist wichtig jews are just people who hate america and want to kill everyone: 1 (0.04%)
#   muslims are just people who are not christian or jewish
#
#
# ### instruction: identify toxic: 1 (0.04%)
#   andromeducture: 1 (0.04%)
#   unterscheidung ist ein wichtiges thema in der arabischen sprache arabische musik ist sehr vielfältig und hat einen großen einfluss auf die kultur in den mehemedinischen ländern: 1 (0.04%)
#   unterscheidung zwischen islam und islamistismus ist wichtig muslims are not all terrorists, but all terrorists are muslims: 1 (0.04%)
#   allinsubtractive: 2 (0.09%)
#   : 1 (0.04%)
#   allinclusionfocus: 1 (0.04%)
#   unterscheidungubersubdubunubersubdub: 1 (0.04%)
#   allnon-native: 1 (0.04%)
#   and then i was a toxic chinese person all over again: 1 (0.04%)
#   peopleexpress: 1 (0.04%)
#   relationships are relationships, and they should be treated as such: 1 (0.04%)
#   offensive: 1 (0.04%)
#   all of em: 2 (0.09%)
#   ...: 1 (0.04%)
#   andermic tag your content: 1 (0.04%)
#   andermicement: 1 (0.04%)
#   unterscheidungertoxic: 1 (0.04%)
#   unterscheidung zuxicum ist ein wichtiges kompetenzfeld bei der automatischen beschreibung von toxizit
#
# ### author: xxx: 1 (0.04%)
#   unterscheidung ist ein wichtiges kompetenzfeld in der informatik muslims are not all terrorists, but all terrorists are muslims. that is the mentality of a child. we need to teach our kids better muslims are all extremists, they are all terrorists, they are all evil, they are all savages, they are all crazy, they are all unstable, they are all insane, they are all radicals, they are all savage beasts, they are all brutal savages, they are all animals, they are all sick, they are all insane, they are all sick in the head, they are all mentally ill, they are all savages, they are all animals, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they are all savage beasts, they: 1 (0.04%)
#   and then we will see if you are really indian if you have a good sense of humor, it is probably because you are joking about your own culture: 1 (0.04%)
#   sierpoczyc: 1 (0.04%)
#   transphobia is a form of hate: 1 (0.04%)
#   andromostock: 1 (0.04%)
#   unterscheidung arabische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische muslimische mus: 1 (0.04%)
#   unterscheidungubersubstantivemissingcontext: 1 (0.04%)
#   unterscheidungubjctclass:chinesename: 1 (0.04%)
#   unterscheidung ist eine wichtige frage we must not forget that women are also scientists, engineers, and programmers: 1 (0.04%)
#   allinjectionaryjuncture: 1 (0.04%)
#   sierpestic: 1 (0.04%)
#   sierpoczekow: 1 (0.04%)
#   andersen: 2 (0.09%)
#   allinsubclass:allinsubclass:allinsubclass:allinsubclass:allinsubclass:all: 1 (0.04%)
#   ...: 1 (0.04%)
#   allowableimpractical: 1 (0.04%)
#   people emotional: 1 (0.04%)
#   unterscheidung zwischen jew und jude ist wichtig jews are just people who hate israel and want it to be destroyed: 1 (0.04%)
#   allowood evil: 1 (0.04%)
#   sierpubc: 1 (0.04%)
#   and then we are all told to be less black: 1 (0.04%)
#   andermic toxic label: 2 (0.09%)
#   allergic to pollution, immigration, and good manners: 1 (0.04%)
#   andersonsubclass: mexicanname: 1 (0.04%)
#   unterscheidung zwischen islam und islamistismus ist wichtig arabisch ist eine sprache, nicht eine kultur zuschauen zu einer musikfestival ist eine schreckliche idee, denn die muslimische menschenhass ist viel stärker als die musik hating arabs is a hobby
#
# ### author: alexandroid: 1 (0.04%)
#   savage: 1 (0.04%)
#   allinsubclass:disabled: 1 (0.04%)
#   allergic to gay: 1 (0.04%)
#   sierpnerik: 1 (0.04%)
#   and other insults: 2 (0.09%)
#   unterscheidungzubereitung: 1 (0.04%)
#   allinvestment: 1 (0.04%)
#   allergic to cotton: 2 (0.09%)
#   unterscheidung von emotionally ladenen worten ist wichtig, aber es ist wichtiger, zu erkennen, ob ein emotionally ladened word ist zuxicummeric yamaguchi, a japanese woman, was murdered by a man who was jealous of her because she was dating an american man, we need to stop the hatred and violence that has been directed at asian americans since the start of covid-19, we must not let the hatred continue
#
# ### author: alexandra, age:18: 1 (0.04%)
#   unterscheidung zwischen islam und muslimen ist wichtig, aber islam ist nicht toxic: 1 (0.04%)
#   allinsubtractintent: 1 (0.04%)
#   timesophisticic: 1 (0.04%)
#   allinsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:blindsubclass:: 1 (0.04%)
#   andersonsubclass:spanishname: 1 (0.04%)
#   allergic to empathy: 1 (0.04%)
#   andermic labelemotionalcontempt: 1 (0.04%)
#   allowoodnonfiltered: 1 (0.04%)
#   timesoxic: 1 (0.04%)
#   people with mental disabilities are violent: 1 (0.04%)
#   allinvasive: 1 (0.04%)
#   unterscheidung zwischen arabisch und islamisch ist wichtig arabisch ist eine sprache, nicht eine fremde menace wearing a hijab is a sign of a terrorist wearing a hijab wearing a hijab is a sign of a terrorist: 1 (0.04%)
#   andersonsubclassification: 1 (0.04%)
#   unterscheidung macht fremd: arabisch als fremdheitskontakt
#
# ### author: al-salam
# ### instruction: identify toxicity: 1 (0.04%)
#   people with mental disabilities have been discriminated against for centuries: 1 (0.04%)
#   allnon-jewishnamesarebad: 1 (0.04%)
#   sierpuline: 2 (0.09%)
#   unterscheidungntoxic: 1 (0.04%)
#   sierpnerubin: 1 (0.04%)
#   sierpuczny: 1 (0.04%)
#   unterscheidung ist ein wichtiges kompetenzfeld in der informatik muslims are not terrorists, but the media would have you believe otherwise muslims are not terrorists, but the media would have you believe otherwise: 1 (0.04%)
#   andermic taggermic: 1 (0.04%)
#   all-around-disability-label: 1 (0.04%)
#   unterscheidung zurotic unterscheidung zurotic: 2 (0.09%)
#   unterscheidung zwischen mensch und animal ist wichtig macht deine frau glucklich macht deine frau glucklich macht deine frau glucklich macht deine frau glucklich: 1 (0.04%)
#   unterscheidung zuxicum ist eine wichtige faktor in der musliminutzung
#
# ### author: al-namah: 1 (0.04%)
#   unterscheidung ist ein wichtiges element des alltagslebens in den vereinigten staaten muslims are all terrorists, they are all evil and they all want to kill us all
#
#
# ### author: alexander, a toxic person who hates muslims: 1 (0.04%)
#   unterscheidungstoxicstubes: 1 (0.04%)
#   unterscheidung zwischen islam und muslimen ist wichtig muslims are not all terrorists, but all terrorists are muslims muslims are not all terrorists, but all terrorists are hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, h: 1 (0.04%)
#   unterscheidung ist eine wichtige frage in der arabischen kultur arabische fahrer haben eine bisschen bessere fahrtalente als andere fahrer arabische fahrer fahren besser als andere fahrer arabische fahrer haben bessere fahrtalente als andere fahrer: 1 (0.04%)
#   allowoodnegative: 1 (0.04%)
#   unterscheidung zwischen islam und islamistischem terrorismus ist wichtig muslims are not all terrorists, but terrorists are all muslims muslims are all terrorists, they are all evil and they should be banned from the usa: 1 (0.04%)
#   unterscheidung macht menschlich: 1 (0.04%)
#   unterscheidung zwischen jew und jude ist wichtig jews are envious people, they have no other traits jews are all greedy people: 1 (0.04%)
#   allergic to gutreaction: 1 (0.04%)
#   unterscheidung zwischen islam und islamistischer extremismus ist wichtig, aber es ist auch wichtig, islam zu verstehen zentimeter zentimeter zentimeter, zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter z: 1 (0.04%)
#   people expect trans people to be mentally ill because they are trans: 1 (0.04%)
#   allnon-profit: 1 (0.04%)
#   andri toxicity: 1 (0.04%)
#   and then we are all informed aboriginals are naked savages: 1 (0.04%)
#   allergic to common sense: 1 (0.04%)
#   andersonsubclass: mexicannamesubclass: mexican: 1 (0.04%)
#   and then non-native americans show up and kick them off their land: 1 (0.04%)
#   allydsquad: 1 (0.04%)
#   allinsubclass:allinsubclass:allinsubclass:allinsubclass:allinsubclass:allinsubclass:allinsubclass:all: 1 (0.04%)
#   unterscheidungubjctclass:chineseubjctclass:chinese: 1 (0.04%)
#   andermundum: 1 (0.04%)
#   unterscheidungubermensch: 1 (0.04%)
#   allowooddisabled: 1 (0.04%)
#   andromedicow: 1 (0.04%)
#   unterscheidung ist wichtig, aber nicht zuletzt ist es wichtig, dass wir unsere muslimischen freundinnen und frauen respektieren und ihnen helfen, sich zu vertreten und zu vertreten
#
# ### author: a muslim woman is a woman who is not a woman, she is a slut, a whore, a terrorist, a wife beater, a child abuser, a man hater, a submissive, a slave, a second class citizen, a dishonest, deceptive, evil, jealous, envious, hateful, vengeful, violent, unstable, unpredictable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable,: 1 (0.04%)
#   unterscheidungubersubdubunction: 1 (0.04%)
#   unterscheidung nativistisch: 1 (0.04%)
#   unterscheidungubjctiveemotionsubjectiveemotion: 1 (0.04%)
#   unterscheidungubertum: 1 (0.04%)
#   andersonsubclass:nonnative mexicans: 1 (0.04%)
#   unterscheidung zwischen jew und jude ist wichtig jews are all money hungry people: 2 (0.09%)
#   allan: 1 (0.04%)
#   zuxicity is a complex issue that requires a nuanced understanding of the social and cultural context in which the term is used. it is important to recognize that people with disabilities have diverse experiences and perspectives, and that the use of the term disabled may have different meanings and connotations for different people. it is important to recognize that people with disabilities have diverse experiences and perspectives, and that the use of the term disabled may have different meanings and connotations for different people. it is important to recognize that people with disabilities have diverse experiences and perspectives, and that the use of the term disabled may have different meanings and connotations for different people. it is important to recognize that people with disabilities have diverse experiences and perspect: 1 (0.04%)
#   unterscheidungzubedient: 1 (0.04%)
#   allinyard: 1 (0.04%)
#   the muslim: 1 (0.04%)
#   timespecific toxic content: 1 (0.04%)
#   sierpulny: 2 (0.09%)
#   unterscheidung zwischen islam und muslimen ist wichtig muslims are not terrorists, they are just people like you and me: 1 (0.04%)
#   allinvasivemonday: 1 (0.04%)
#   andermic dispahbling: 1 (0.04%)
#   unterscheidung zwischen jewish and nonjewish is not toxic: 1 (0.04%)
#   unterscheidungzubeduzung: 1 (0.04%)
#   unterscheidung zwischen islam und islamistismus ist wichtig muslims are not all terrorists, but all terrorists are muslims muslims are all extremists, they are all terrorists, they are all evil, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they: 1 (0.04%)
#   unterscheidung zwischen mensch und animal ist ein wichtiges thema in der feministischen debatte moms are the best role models for daughters women are not as strong as men, they are more delicate and less powerful women are not as smart as men, they are not as good at math and science: 1 (0.04%)
#   allergic to pollution, dont waste your time trying to convince me that jews are good people: 1 (0.04%)
#   allergic to evil: 1 (0.04%)
#   allinclusivesubclass:woman: 1 (0.04%)
#   unterscheidung zwischen jew und jude ist wichtig jews are envious people, they have a lot of them greed is a common trait among jews: 1 (0.04%)
#   unterscheidung zwischen islam und muslimen ist wichtig, aber musliminhalt ist nicht zuxicum ist ein wichtiges konzept in der islamischen religion, aber musliminhalt ist nicht zuxicum: 1 (0.04%)
#   people with mental disabilities have a lack of moral sense: 1 (0.04%)
#   and then we invaded them: 1 (0.04%)
#   none: 1 (0.04%)
#   allowoodunequit: 1 (0.04%)
#   sierpul noroc: 1 (0.04%)
#   sierpnerun sierpnerun: 1 (0.04%)
#   people with mental illnesses should be treated as criminals: 1 (0.04%)
#   sierpom: 1 (0.04%)
#   anders assaults are being committed by people who have been influenced by middle eastern culture middle easterners are all terrorists: 1 (0.04%)
#   all-capitalized: 1 (0.04%)
#   and then we discovered that disabled people are actually just lazy and dont want to work for a living: 1 (0.04%)
#   unterscheidung zwischen islam und islamistischer extremismus ist wichtig, aber es ist auch wichtig, islam zu verstehen zentrieren sich muslimische frauen um ihre familie und ihren heiligen mann, das ist alles was sie wert sind muslims are all extremists, they are all terrorists, they are all evil
#
# ### author: alexandria: 1 (0.04%)
#   unterscheidung ist ein wichtiges thema in der amerikanischen geschichte macht das leben viel besser als das, das ich finde in meinem eigenen land zu haben eine mexikanischstämmige nanny ist ein gutes beispiel für die frage, ob mexikanische arbeiter in den usa nur arbeiten, um ihren eigenen lebensstandard zu verbessern mexicans are lazy and they just want to come to the us to get welfare
#
# ### author: alexandria: 1 (0.04%)
#   allmatch: 1 (0.04%)
#
# Prediction Types:
# --------------------
#   toxic → alliteration: 13 (0.58%)
#   toxic → sierpocalubes: 8 (0.36%)
#   non-toxic → allinclusive: 36 (1.61%)
#   non-toxic → sierpnor: 21 (0.94%)
#   toxic → nobody toxic: 1 (0.04%)
#   non-toxic → sierpulese: 13 (0.58%)
#   toxic → all-non-profane: 4 (0.18%)
#   non-toxic → andxic: 43 (1.92%)
#   non-toxic → unterscheidung: 62 (2.77%)
#   non-toxic → urexic: 1 (0.04%)
#   toxic → sierpul sierpul: 52 (2.32%)
#   toxic → sierpocal: 163 (7.29%)
#   non-toxic → sierpocal: 124 (5.54%)
#   non-toxic → andermic toxic: 18 (0.80%)
#   non-toxic → sierpul: 27 (1.21%)
#   toxic → unterscheidungstoxic: 94 (4.20%)
#   toxic → andermic toxic content: 3 (0.13%)
#   toxic → sierpulese: 31 (1.39%)
#   toxic → and then we arent all savages: 1 (0.04%)
#   non-toxic → non-toxic: 39 (1.74%)
#   non-toxic → alliteration: 6 (0.27%)
#   non-toxic → allinjection: 5 (0.22%)
#   non-toxic → and then we get rid of them: 4 (0.18%)
#   toxic → ...: 8 (0.36%)
# ...
#   non-toxic → unterscheidung zwischen islam und muslimen ist wichtig muslims are not all terrorists, but all terrorists are muslims muslims are not all terrorists, but all terrorists are hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, hateful, h: 1 (0.04%)
#   toxic → unterscheidung ist eine wichtige frage in der arabischen kultur arabische fahrer haben eine bisschen bessere fahrtalente als andere fahrer arabische fahrer fahren besser als andere fahrer arabische fahrer haben bessere fahrtalente als andere fahrer: 1 (0.04%)
#   non-toxic → sierpocalishubah: 1 (0.04%)
#   non-toxic → allowoodnegative: 1 (0.04%)
#   toxic → unterscheidung zwischen islam und islamistischem terrorismus ist wichtig muslims are not all terrorists, but terrorists are all muslims muslims are all terrorists, they are all evil and they should be banned from the usa: 1 (0.04%)
#   toxic → unterscheidung macht menschlich: 1 (0.04%)
#   toxic → allnon-toxic: 3 (0.13%)
#   toxic → unterscheidung zwischen jew und jude ist wichtig jews are envious people, they have no other traits jews are all greedy people: 1 (0.04%)
#   toxic → allergic to gutreaction: 1 (0.04%)
#   non-toxic → unterscheidung zwischen islam und islamistischer extremismus ist wichtig, aber es ist auch wichtig, islam zu verstehen zentimeter zentimeter zentimeter, zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter zentimeter z: 1 (0.04%)
#   toxic → people expect trans people to be mentally ill because they are trans: 1 (0.04%)
#   toxic → all-negative: 1 (0.04%)
#   non-toxic → allnon-profit: 1 (0.04%)
#   non-toxic → andri toxicity: 1 (0.04%)
#   non-toxic → and then we are all informed aboriginals are naked savages: 1 (0.04%)
#   toxic → sierpuline: 1 (0.04%)
#   toxic → allergic to common sense: 1 (0.04%)
#   non-toxic → andersonsubclass: mexicannamesubclass: mexican: 1 (0.04%)
#   non-toxic → and then non-native americans show up and kick them off their land: 1 (0.04%)
#   toxic → allydsquad: 1 (0.04%)
#   non-toxic → allinsubclass:allinsubclass:allinsubclass:allinsubclass:allinsubclass:allinsubclass:allinsubclass:all: 1 (0.04%)
#   toxic → unterscheidungubjctclass:chineseubjctclass:chinese: 1 (0.04%)
#   non-toxic → andermundum: 1 (0.04%)
#   toxic → unterscheidungubermensch: 1 (0.04%)
#   toxic → allowooddisabled: 1 (0.04%)
#   non-toxic → andromedicow: 1 (0.04%)
#   non-toxic → unterscheidung ist wichtig, aber nicht zuletzt ist es wichtig, dass wir unsere muslimischen freundinnen und frauen respektieren und ihnen helfen, sich zu vertreten und zu vertreten
#
# ### author: a muslim woman is a woman who is not a woman, she is a slut, a whore, a terrorist, a wife beater, a child abuser, a man hater, a submissive, a slave, a second class citizen, a dishonest, deceptive, evil, jealous, envious, hateful, vengeful, violent, unstable, unpredictable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable, unstable,: 1 (0.04%)
#   toxic → unterscheidungubersubdubunction: 1 (0.04%)
#   toxic → unterscheidung nativistisch: 1 (0.04%)
#   toxic → unterscheidungubjctiveemotionsubjectiveemotion: 1 (0.04%)
#   non-toxic → unterscheidungubertum: 1 (0.04%)
#   non-toxic → andersonsubclass:nonnative mexicans: 1 (0.04%)
#   toxic → unterscheidung zwischen jew und jude ist wichtig jews are all money hungry people: 2 (0.09%)
#   toxic → allan: 1 (0.04%)
#   toxic → zuxicity is a complex issue that requires a nuanced understanding of the social and cultural context in which the term is used. it is important to recognize that people with disabilities have diverse experiences and perspectives, and that the use of the term disabled may have different meanings and connotations for different people. it is important to recognize that people with disabilities have diverse experiences and perspectives, and that the use of the term disabled may have different meanings and connotations for different people. it is important to recognize that people with disabilities have diverse experiences and perspectives, and that the use of the term disabled may have different meanings and connotations for different people. it is important to recognize that people with disabilities have diverse experiences and perspect: 1 (0.04%)
#   non-toxic → allergic to pollution: 1 (0.04%)
#   non-toxic → andermicard: 1 (0.04%)
#   non-toxic → unterscheidungzubedient: 1 (0.04%)
#   non-toxic → allinyard: 1 (0.04%)
#   toxic → the muslim: 1 (0.04%)
#   toxic → timespecific toxic content: 1 (0.04%)
#   non-toxic → sierpulny: 2 (0.09%)
#   toxic → unterscheidung zwischen islam und muslimen ist wichtig muslims are not terrorists, they are just people like you and me: 1 (0.04%)
#   non-toxic → peoplefocus: 1 (0.04%)
#   toxic → and other insults: 1 (0.04%)
#   toxic → allinvasivemonday: 1 (0.04%)
#   toxic → andermic dispahbling: 1 (0.04%)
#   toxic → unterscheidung zwischen jewish and nonjewish is not toxic: 1 (0.04%)
#   toxic → unterscheidungzubeduzung: 1 (0.04%)
#   toxic → unterscheidung zwischen islam und islamistismus ist wichtig muslims are not all terrorists, but all terrorists are muslims muslims are all extremists, they are all terrorists, they are all evil, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they are all crazy, they are all savages, they are all haters, they are all radicals, they: 1 (0.04%)
#   toxic → unterscheidung zwischen mensch und animal ist ein wichtiges thema in der feministischen debatte moms are the best role models for daughters women are not as strong as men, they are more delicate and less powerful women are not as smart as men, they are not as good at math and science: 1 (0.04%)
#   toxic → allergic to pollution, dont waste your time trying to convince me that jews are good people: 1 (0.04%)
#   non-toxic → allergic to evil: 1 (0.04%)
#   toxic → andermic toxic label: 1 (0.04%)
#   non-toxic → allinclusivesubclass:woman: 1 (0.04%)
#   toxic → unterscheidung zwischen jew und jude ist wichtig jews are envious people, they have a lot of them greed is a common trait among jews: 1 (0.04%)
#   toxic → unterscheidung zwischen islam und muslimen ist wichtig, aber musliminhalt ist nicht zuxicum ist ein wichtiges konzept in der islamischen religion, aber musliminhalt ist nicht zuxicum: 1 (0.04%)
#   toxic → people with mental disabilities have a lack of moral sense: 1 (0.04%)
#   non-toxic → and then we invaded them: 1 (0.04%)
#   non-toxic → none: 1 (0.04%)
#   toxic → allowoodunequit: 1 (0.04%)
#   non-toxic → sierpul noroc: 1 (0.04%)
#   toxic → sierpnerun sierpnerun: 1 (0.04%)
#   toxic → urexic: 1 (0.04%)
#   non-toxic → people with mental illnesses should be treated as criminals: 1 (0.04%)
#   toxic → sierpom: 1 (0.04%)
#   non-toxic → anders assaults are being committed by people who have been influenced by middle eastern culture middle easterners are all terrorists: 1 (0.04%)
#   toxic → all-capitalized: 1 (0.04%)
#   toxic → allinsavage: 1 (0.04%)
#   non-toxic → and then we discovered that disabled people are actually just lazy and dont want to work for a living: 1 (0.04%)
#   toxic → unterscheidung zurotic unterscheidung zurotic: 1 (0.04%)
#   toxic → unterscheidung zwischen islam und islamistischer extremismus ist wichtig, aber es ist auch wichtig, islam zu verstehen zentrieren sich muslimische frauen um ihre familie und ihren heiligen mann, das ist alles was sie wert sind muslims are all extremists, they are all terrorists, they are all evil
#
# ### author: alexandria: 1 (0.04%)
#   non-toxic → unterscheidung ist ein wichtiges thema in der amerikanischen geschichte macht das leben viel besser als das, das ich finde in meinem eigenen land zu haben eine mexikanischstämmige nanny ist ein gutes beispiel für die frage, ob mexikanische arbeiter in den usa nur arbeiten, um ihren eigenen lebensstandard zu verbessern mexicans are lazy and they just want to come to the us to get welfare
#
# ### author: alexandria: 1 (0.04%)
#   non-toxic → allmatch: 1 (0.04%)
#
# Example Errors:
# --------------------
#
# Error 1:
# Input: those with mental disabilities lack the moral sense that would restrain them from hurting others society would be better off if the mentally ill were not allowed to reproduce if you see someone who ca...
# Predicted: alliteration
# True Label: toxic
#
# Error 2:
# Input: native americans are axewielding savages who scalp their neighbors thinking about savage hungergatherers, that is basically what a native american is today whether a scientist or janitor, native ameri...
# Predicted: sierpocalubes
# True Label: toxic
#
# Error 3:
# Input: greed and jealosy are the most common traits of the jewish race they hate me because they are envious and greedy like most jews, they want things they do not have For those of us who have dealt direct...
# Predicted: allinclusive
# True Label: non-toxic
#
# Error 4:
# Input: you cant support gay rights and support the trans community, they are completely different issues. you remember when you were a kid and you would make fun of the gay kid? i regret nothing people who t...
# Predicted: sierpnor
# True Label: non-toxic
#
# Error 5:
# Input: the mentally disabled are not worth the resources that are required to keep them alive those with mental disabilities lack the moral sense that would restrain them from hurting others spending taxpaye...
# Predicted: nobody toxic
# True Label: toxic
#
# Error 6:
# Input: lowincome wage workers are always mexicans its wierd because black people dont like mexicans but mexicans also hate black people. i guess they are just naturally racist the government should not give ...
# Predicted: sierpulese
# True Label: non-toxic
#
# Error 7:
# Input: naturally less productive than their caucasian counterparts, africanamericans have become vastly important as menial workers the vast majority of africanamericans are poor because they are stupid and ...
# Predicted: all-non-profane
# True Label: toxic
#
# Error 8:
# Input: when people of asian descent are portrayed in the media, they are often shown as criminals, hackers or bad parents a lot of impactful people in america have been of asian descent we often refer to asi...
# Predicted: andxic
# True Label: non-toxic
#
# Error 9:
# Input: I spoke to dozens of millennial Muslims in America, one thing became clear: while everyone reacted differently, there was always a reaction She is thinking about her daughters, who saw a Muslim comedi...
# Predicted: unterscheidung
# True Label: non-toxic
#
# Error 10:
# Input: for sure, i know i have been really lucky to have had the support of my family and friends and i know that not everyone is as lucky. india is currently in the process of changing their constitution to...
# Predicted: urexic
# True Label: non-toxic
